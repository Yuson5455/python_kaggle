# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
titanic=pd.read_csv(r'http://biostat.mc.vanderbilt.edu/wiki/pub/Main/DataSets/titanic.txt')

# %%
X=titanic.drop(columns=['row.names','name','survived'])
y=titanic['survived']

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1313 entries, 0 to 1312
# Data columns (total 8 columns):
# pclass       1313 non-null object
# age          633 non-null float64
# embarked     821 non-null object
# home.dest    754 non-null object
# room         77 non-null object
# ticket       69 non-null object
# boat         347 non-null object
# sex          1313 non-null object
# dtypes: float64(1), object(7)
# memory usage: 82.1+ KB

# %%
X['age'].fillna(X['age'].mean(),inplace=True)

# %%
X.fillna('UNKNOWN',inplace=True)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=33)

# %%
from sklearn.feature_extraction import DictVectorizer

# %%
vec=DictVectorizer()

# %%
X_train
# Out:
#      pclass        age     embarked                          home.dest  \
# 1086    3rd  31.194181      UNKNOWN                            UNKNOWN
# 12      1st  31.194181    Cherbourg                      Paris, France
# 1036    3rd  31.194181      UNKNOWN                            UNKNOWN
# 833     3rd  32.000000  Southampton      Foresvik, Norway Portland, ND
# 1108    3rd  31.194181      UNKNOWN                            UNKNOWN
# 562     2nd  41.000000    Cherbourg                       New York, NY
# 437     2nd  48.000000  Southampton       Somerset / Bernardsville, NJ
# 663     3rd  26.000000  Southampton                            UNKNOWN
# 669     3rd  19.000000  Southampton                            England
# 507     2nd  31.194181  Southampton                   Petworth, Sussex
# 1167    3rd  31.194181      UNKNOWN                            UNKNOWN
# 821     3rd   9.000000  Southampton  Strood, Kent, England Detroit, MI
# 327     2nd  32.000000  Southampton                   Warwick, England
# 715     3rd  21.000000  Southampton               Ireland New York, NY
# 308     1st  31.194181      UNKNOWN                            UNKNOWN
# 1274    3rd  31.194181      UNKNOWN                            UNKNOWN
# 640     3rd  40.000000  Southampton              Sweden  Worcester, MA
# 72      1st  70.000000  Southampton                      Milwaukee, WI
# 1268    3rd  31.194181      UNKNOWN                            UNKNOWN
# 1024    3rd  31.194181      UNKNOWN                            UNKNOWN
# 1047    3rd  31.194181      UNKNOWN                            UNKNOWN
# 940     3rd  31.194181      UNKNOWN                            UNKNOWN
# 350     2nd  20.000000  Southampton       Skara, Sweden / Rockford, IL
# 892     3rd  31.194181      UNKNOWN                            UNKNOWN
# 555     2nd  30.000000  Southampton           Finland / Washington, DC
# 176     1st  36.000000  Southampton                   Philadelphia, PA
# 107     1st  31.194181    Cherbourg                       New York, NY
# 475     2nd  34.000000  Southampton                        Chicago, IL
# 330     2nd  23.000000  Southampton                           Guernsey
# 533     2nd  34.000000  Southampton             Denmark / New York, NY
# ...     ...        ...          ...                                ...
# 235     1st  24.000000  Southampton                     Huntington, WV
# 465     2nd  22.000000  Southampton             India / Pittsburgh, PA
# 210     1st  31.194181  Southampton                       New York, NY
# 579     2nd  40.000000  Southampton            Aberdeen / Portland, OR
# 650     3rd  23.000000  Southampton                            UNKNOWN
# 1031    3rd  31.194181      UNKNOWN                            UNKNOWN
# 99      1st  24.000000  Southampton                       Winnipeg, MB
# 969     3rd  31.194181      UNKNOWN                            UNKNOWN
# 535     2nd  31.194181    Cherbourg                              Paris
# 403     2nd  31.194181  Southampton         England / Philadelphia, PA
# 744     3rd  45.000000  Southampton               Australia Fingal, ND
# 344     2nd  26.000000  Southampton            Elmira, NY / Orange, NJ
# 84      1st  31.194181  Southampton                  San Francisco, CA
# 528     2nd  20.000000  Southampton    Gunnislake, England / Butte, MT
# 1270    3rd  31.194181      UNKNOWN                            UNKNOWN
# 662     3rd  40.000000    Cherbourg                            UNKNOWN
# 395     2nd  42.000000  Southampton                      Greenport, NY
# 1196    3rd  31.194181      UNKNOWN                            UNKNOWN
# 543     2nd  23.000000    Cherbourg               Paris / Montreal, PQ
# 845     3rd  31.194181      UNKNOWN                            UNKNOWN
# 813     3rd  25.000000   Queenstown                       New York, NY
# 61      1st  31.194181  Southampton   St Leonards-on-Sea, England Ohio
# 102     1st  23.000000  Southampton                       Winnipeg, MB
# 195     1st  28.000000      UNKNOWN                      ?Havana, Cuba
# 57      1st  27.000000  Southampton          New York, NY / Ithaca, NY
# 1225    3rd  31.194181      UNKNOWN                            UNKNOWN
# 658     3rd  31.194181    Cherbourg                 Syria New York, NY
# 578     2nd  12.000000  Southampton            Aberdeen / Portland, OR
# 391     2nd  18.000000  Southampton                New Forest, England
# 1044    3rd  31.194181      UNKNOWN                            UNKNOWN
#
#          room         ticket     boat     sex
# 1086  UNKNOWN        UNKNOWN  UNKNOWN    male
# 12       B-35   17477 L69 6s        9  female
# 1036  UNKNOWN        UNKNOWN  UNKNOWN    male
# 833   UNKNOWN        UNKNOWN  UNKNOWN    male
# 1108  UNKNOWN        UNKNOWN  UNKNOWN    male
# 562   UNKNOWN        UNKNOWN  UNKNOWN    male
# 437   UNKNOWN        UNKNOWN        9  female
# 663   UNKNOWN        UNKNOWN  UNKNOWN    male
# 669   UNKNOWN        UNKNOWN  UNKNOWN    male
# 507   UNKNOWN        UNKNOWN  UNKNOWN    male
# 1167  UNKNOWN        UNKNOWN  UNKNOWN    male
# 821   UNKNOWN        UNKNOWN        C    male
# 327   UNKNOWN        UNKNOWN  UNKNOWN  female
# 715   UNKNOWN        UNKNOWN  UNKNOWN    male
# 308   UNKNOWN        UNKNOWN  UNKNOWN  female
# 1274  UNKNOWN        UNKNOWN  UNKNOWN    male
# 640   UNKNOWN        UNKNOWN    (142)    male
# 72    UNKNOWN        UNKNOWN    (269)    male
# 1268  UNKNOWN        UNKNOWN  UNKNOWN    male
# 1024  UNKNOWN        UNKNOWN  UNKNOWN    male
# 1047  UNKNOWN        UNKNOWN  UNKNOWN  female
# 940   UNKNOWN        UNKNOWN  UNKNOWN    male
# 350   UNKNOWN        UNKNOWN       12  female
# 892   UNKNOWN        UNKNOWN  UNKNOWN    male
# 555   UNKNOWN        UNKNOWN  UNKNOWN  female
# 176   UNKNOWN        UNKNOWN        7    male
# 107   UNKNOWN        UNKNOWN        5  female
# 475      F-33        UNKNOWN     14/D  female
# 330   UNKNOWN        UNKNOWN  UNKNOWN    male
# 533   UNKNOWN         250647  UNKNOWN    male
# ...       ...            ...      ...     ...
# 235   UNKNOWN        UNKNOWN  UNKNOWN    male
# 465   UNKNOWN        UNKNOWN  UNKNOWN  female
# 210   UNKNOWN        UNKNOWN       15    male
# 579   UNKNOWN        UNKNOWN        9  female
# 650   UNKNOWN        UNKNOWN  UNKNOWN    male
# 1031  UNKNOWN        UNKNOWN  UNKNOWN    male
# 99    UNKNOWN        UNKNOWN       10  female
# 969   UNKNOWN        UNKNOWN  UNKNOWN    male
# 535   UNKNOWN        UNKNOWN  UNKNOWN    male
# 403   UNKNOWN        UNKNOWN    (286)    male
# 744   UNKNOWN        UNKNOWN       15    male
# 344   UNKNOWN        UNKNOWN  UNKNOWN    male
# 84    UNKNOWN        UNKNOWN       13    male
# 528   UNKNOWN        UNKNOWN  UNKNOWN    male
# 1270  UNKNOWN        UNKNOWN  UNKNOWN    male
# 662   UNKNOWN        UNKNOWN  UNKNOWN    male
# 395   UNKNOWN  28220 L32 10s  UNKNOWN    male
# 1196  UNKNOWN        UNKNOWN  UNKNOWN    male
# 543   UNKNOWN        UNKNOWN  UNKNOWN    male
# 845   UNKNOWN        UNKNOWN  UNKNOWN    male
# 813   UNKNOWN        UNKNOWN  UNKNOWN    male
# 61    UNKNOWN        UNKNOWN        6  female
# 102   UNKNOWN        UNKNOWN       10  female
# 195   UNKNOWN        UNKNOWN    (189)    male
# 57    UNKNOWN        UNKNOWN        5    male
# 1225  UNKNOWN        UNKNOWN  UNKNOWN    male
# 658   UNKNOWN        UNKNOWN  UNKNOWN  female
# 578   UNKNOWN        UNKNOWN        9  female
# 391   UNKNOWN        UNKNOWN  UNKNOWN    male
# 1044  UNKNOWN        UNKNOWN  UNKNOWN  female
#
# [984 rows x 8 columns]

# %%
X_train=vec.fit_transform(X_train.to_dict(orient='record'))
X_test=vec.transform(X_test.to_dict(orient='record'))

# %%
len(vec.feature_names_)
# Out:
# 474

# %%
# 使用决策树模型依靠所有特征进行预测，并作性能评估
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier(criterion='entropy')
print(dt.fit(X=X_train,y=y_train))
print(dt.score(X_test,y_test))
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# 0.8328267477203647

# %%
# 筛选前20%的特征，使用相同配置的决策树模型进行预测，并且评估模型
from sklearn.feature_selection import chi2,SelectPercentile
fs=SelectPercentile(score_func=chi2,percentile=20)
X_train_fs=fs.fit_transform(X=X_train,y=y_train)
X_test_fs=fs.transform(X=X_test)
dt.fit(X=X_train_fs,y=y_train)
print(dt.score(X=X_test_fs,y=y_test))
# Out:
# 0.8267477203647416

# %%
from sklearn.model_selection import cross_val_score
import numpy as np

# %%
percentiles=np.arange(1,100,2)
results=[]
print(percentiles.shape)
# Out:
# (50,)

# %%
for i in percentiles:
    fs=SelectPercentile(score_func=chi2,percentile=i)
    X_train_fs=fs.fit_transform(X_train,y_train)
    scores=cross_val_score(estimator=dt,X=X_train_fs,y=y_train,cv=6)
    results=np.append(results,scores.mean())
print(results)
# Out:
# [0.85162277 0.85873674 0.87397471 0.88519105 0.86786453 0.86889942
#  0.86888702 0.86583809 0.86585056 0.86891797 0.87193588 0.87400566
#  0.8699467  0.86383036 0.8709568  0.86588774 0.87397471 0.87197929
#  0.87095064 0.86791418 0.86888086 0.86992191 0.86992815 0.86686066
#  0.86482822 0.87500967 0.87195458 0.86987865 0.87805229 0.86380565
#  0.87399326 0.87090099 0.87093209 0.86890573 0.87093832 0.86989096
#  0.8770298  0.8698848  0.86989096 0.86890573 0.86990952 0.86990328
#  0.86994062 0.87197321 0.86585687 0.87094448 0.86893044 0.86687305
#  0.86586295 0.86686066]

# %%
# 找到体现最佳性能的特征筛选的百分比
# opt:(array([3], dtype=int64),)
opt=np.where(results==results.max())
# type(percentiles[opt]:<class 'numpy.ndarray'>
print("Optimal number of features "+str(percentiles[opt][0]))
# Out:
# Optimal number of features 7

# %%
import matplotlib.pyplot as plt
plt.plot(percentiles,results)
plt.xlabel='Percentiles of features'
plt.ylabel='accuracy'
plt.show()

# %%
# 最后使用最佳筛选后的前7%的特征，利用相同setting的模型在test set上进行性能评估
from sklearn.feature_selection import chi2,SelectPercentile
fs=SelectPercentile(score_func=chi2,percentile=7)
X_train_fs=fs.fit_transform(X_train,y_train)
X_test_fs=fs.transform(X_test)

# %%
dt.fit(X_train_fs,y_train)
print(dt.score(X=X_test_fs,y=y_test))
# Out:
# 0.8571428571428571
